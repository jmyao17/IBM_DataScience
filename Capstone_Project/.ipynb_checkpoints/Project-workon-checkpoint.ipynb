# %% [markdown]
# # Best Place for an Asian Restaurant in Lasing Capital Area

# %% [markdown]
# ##  Introduction/Business Problem
#
#
# The client is looking to open an Asian restaurant in Lansing Capital Area (Lansing, East Lansing, Okemos, Haslett, Mason, and Holt), MI.
# The location is very important to him as he needs the location of the restaurant fulfills the following considerations:
# + In which region, the most favorite restaurant is an Asian restaurant.
# + The population in the region should not be too small.
#
# In this project, we are interested in restaurants.
# We will use the popularity of the restaurant and population in this zip code region to cluster the venues.

# %% [markdown]
# ##   Data source
#
# + All Americal's zipcode data can be found on the website: https://simplemaps.com/data/us-zips.
# + The website of https://www.zipdatamaps.com/{zipcode} provide more details information for each zip code region.
# + With the zipcode of each region, we can use Foursquare to locate venues in each zipcode region.
# Then we will analyze the venues with venue category related to the restaurant.
# Using popularity of the restaurant and population in the region to cluster these venues by machine learning method.

# %% [markdown]
# #### Load modules

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import folium # map rendering library
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import json # library to handle JSON files
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Get data and clean data
#
# Get geospatial information of Lansing Capital Area.

# %%
path='uszipsv1.4.csv'
gosdf = pd.read_csv(path)
gosdf.head()
# Out:
#    zip      lat      lng        city state_id   state_name   zcta  \
# 0  501  40.8133 -73.0476  Holtsville       NY     New York  False
# 1  544  40.8133 -73.0476  Holtsville       NY     New York  False
# 2  601  18.1800 -66.7522    Adjuntas       PR  Puerto Rico   True
# 3  602  18.3607 -67.1752      Aguada       PR  Puerto Rico   True
# 4  603  18.4544 -67.1220   Aguadilla       PR  Puerto Rico   True
#
#    parent_zcta  population  county_fips  county_name  \
# 0      11742.0         NaN          NaN          NaN
# 1      11742.0         NaN          NaN          NaN
# 2          NaN     18570.0      72001.0      72001.0
# 3          NaN     41520.0      72003.0      72003.0
# 4          NaN     54689.0      72005.0      72005.0
#
#              all_county_weights  imprecise  military
# 0                           NaN       True     False
# 1                           NaN       True     False
# 2  {'72001':99.43,'72141':0.57}      False     False
# 3                 {'72003':100}      False     False
# 4                 {'72005':100}      False     False

# %%
GreatLansing = gosdf[(gosdf['city'] == 'Lansing') | (gosdf['city'] == 'Okemos') | (gosdf['city'] == 'East Lansing')|(gosdf['city'] == 'Haslett')|(gosdf['city'] == 'Mason')|(gosdf['city'] == 'Holt')]
LansingMI = GreatLansing[GreatLansing['state_id'] =='MI']
LansingMI.head()
# Out:
#          zip      lat      lng          city state_id state_name   zcta  \
# 20914  48805  42.7082 -84.4144        Okemos       MI   Michigan  False
# 20930  48823  42.7620 -84.4539  East Lansing       MI   Michigan   True
# 20931  48824  42.7229 -84.4751  East Lansing       MI   Michigan  False
# 20932  48825  42.7270 -84.4809  East Lansing       MI   Michigan   True
# 20933  48826  42.7360 -84.4843  East Lansing       MI   Michigan  False
#
#        parent_zcta  population  county_fips  county_name  \
# 20914      48864.0         NaN          NaN          NaN
# 20930          NaN     51302.0      26065.0      26065.0
# 20931      48825.0         NaN          NaN          NaN
# 20932          NaN     12596.0      26065.0      26065.0
# 20933      48823.0         NaN          NaN          NaN
#
#                 all_county_weights  imprecise  military
# 20914                          NaN       True     False
# 20930  {'26037':14.5,'26065':85.5}      False     False
# 20931                          NaN      False     False
# 20932                {'26065':100}      False     False
# 20933                          NaN       True     False

# %% [markdown]
# ###  Remove duplicate value.

# %%
lasing = LansingMI[['zip','lat','lng','city','population']].drop_duplicates(['zip']).copy()
lasing.zip = lasing['zip'].astype('str')
lasing = lasing.drop_duplicates(['lat','lng']).copy()
lasing
# Out:
#          zip      lat      lng          city  population
# 20914  48805  42.7082 -84.4144        Okemos         NaN
# 20930  48823  42.7620 -84.4539  East Lansing     51302.0
# 20931  48824  42.7229 -84.4751  East Lansing         NaN
# 20932  48825  42.7270 -84.4809  East Lansing     12596.0
# 20933  48826  42.7360 -84.4843  East Lansing         NaN
# 20945  48840  42.7690 -84.3707       Haslett     12501.0
# 20947  48842  42.6338 -84.5387          Holt     20432.0
# 20959  48854  42.5820 -84.4517         Mason     18598.0
# 20968  48864  42.7013 -84.4067        Okemos     20148.0
# 21000  48901  42.7091 -84.5540       Lansing         NaN
# 21001  48906  42.7845 -84.5875       Lansing     26634.0
# 21003  48909  42.7311 -84.5526       Lansing         NaN
# 21004  48910  42.6985 -84.5230       Lansing     34560.0
# 21005  48911  42.6745 -84.5709       Lansing     40111.0
# 21006  48912  42.7402 -84.5235       Lansing     17035.0
# 21008  48915  42.7383 -84.5710       Lansing      9218.0
# 21010  48917  42.7238 -84.6400       Lansing     32062.0
# 21011  48918  40.2439 -87.1261       Lansing         NaN
# 21017  48933  42.7325 -84.5543       Lansing      2530.0
# 21019  48951  42.7300 -84.5622       Lansing         NaN

# %% [markdown]
# ###  Remove outlier value.
# There is a outlier value, which is (40.2439,-87.1261) for zip=48918. We need to remove this outlier value from our dataframe.

# %%
lasing = lasing[np.abs(lasing.lat-lasing.lat.mean()) <= (3*lasing.lat.std())]
lasing = lasing.sort_values(by=['zip'])
lasing.reset_index(inplace=True)
lasing
# Out:
#     index    zip      lat      lng          city  population
# 0   20914  48805  42.7082 -84.4144        Okemos         NaN
# 1   20930  48823  42.7620 -84.4539  East Lansing     51302.0
# 2   20931  48824  42.7229 -84.4751  East Lansing         NaN
# 3   20932  48825  42.7270 -84.4809  East Lansing     12596.0
# 4   20933  48826  42.7360 -84.4843  East Lansing         NaN
# 5   20945  48840  42.7690 -84.3707       Haslett     12501.0
# 6   20947  48842  42.6338 -84.5387          Holt     20432.0
# 7   20959  48854  42.5820 -84.4517         Mason     18598.0
# 8   20968  48864  42.7013 -84.4067        Okemos     20148.0
# 9   21000  48901  42.7091 -84.5540       Lansing         NaN
# 10  21001  48906  42.7845 -84.5875       Lansing     26634.0
# 11  21003  48909  42.7311 -84.5526       Lansing         NaN
# 12  21004  48910  42.6985 -84.5230       Lansing     34560.0
# 13  21005  48911  42.6745 -84.5709       Lansing     40111.0
# 14  21006  48912  42.7402 -84.5235       Lansing     17035.0
# 15  21008  48915  42.7383 -84.5710       Lansing      9218.0
# 16  21010  48917  42.7238 -84.6400       Lansing     32062.0
# 17  21017  48933  42.7325 -84.5543       Lansing      2530.0
# 18  21019  48951  42.7300 -84.5622       Lansing         NaN

# %% [markdown]
# Remove **index** column

# %%
lasing = lasing.drop('index',axis=1)
lasing
# Out:
#       zip      lat      lng          city  population
# 0   48805  42.7082 -84.4144        Okemos         NaN
# 1   48823  42.7620 -84.4539  East Lansing     51302.0
# 2   48824  42.7229 -84.4751  East Lansing         NaN
# 3   48825  42.7270 -84.4809  East Lansing     12596.0
# 4   48826  42.7360 -84.4843  East Lansing         NaN
# 5   48840  42.7690 -84.3707       Haslett     12501.0
# 6   48842  42.6338 -84.5387          Holt     20432.0
# 7   48854  42.5820 -84.4517         Mason     18598.0
# 8   48864  42.7013 -84.4067        Okemos     20148.0
# 9   48901  42.7091 -84.5540       Lansing         NaN
# 10  48906  42.7845 -84.5875       Lansing     26634.0
# 11  48909  42.7311 -84.5526       Lansing         NaN
# 12  48910  42.6985 -84.5230       Lansing     34560.0
# 13  48911  42.6745 -84.5709       Lansing     40111.0
# 14  48912  42.7402 -84.5235       Lansing     17035.0
# 15  48915  42.7383 -84.5710       Lansing      9218.0
# 16  48917  42.7238 -84.6400       Lansing     32062.0
# 17  48933  42.7325 -84.5543       Lansing      2530.0
# 18  48951  42.7300 -84.5622       Lansing         NaN

# %% [markdown]
# ### Get the population number from internet for Nan value.
# Get the index Number for population equals to **NaN**

# %%
lax = lasing.index[lasing['population'].isnull()]
lax
# Out:
# Int64Index([0, 2, 4, 9, 11, 18], dtype='int64')

# %% [markdown]
# From https://www.zipdatamaps.com/{zipcode} website to obtain the population number and add to dataframe

# %%
for index in lax:
    zipcode = lasing.iloc[index].zip
    url_address = 'https://www.zipdatamaps.com/{}'.format(zipcode)
    url=requests.get(url_address).text
    soup = BeautifulSoup(url,'lxml')
    table = soup.find('table',{'class':'table table-striped table-bordered table-hover table-condensed'})
    lists=[]
    for row in table.findAll("tr"):
        cells = row.findAll("td")
        items = [th.text.strip() for th in cells]
        lists.append(items)
    
    df=pd.DataFrame(lists[0:])
    zip_population = df.loc[5,1]
    lasing.at[index,'population'] = df.loc[5,1] 
    print('zipcode :',zipcode,'   population = ',zip_population)
# Out:
# zipcode : 48805    population =  0
# zipcode : 48824    population =  1158
# zipcode : 48826    population =  0
# zipcode : 48901    population =  0
# zipcode : 48909    population =  0
# zipcode : 48951    population =  0

# %%
lasing
# Out:
#       zip      lat      lng          city  population
# 0   48805  42.7082 -84.4144        Okemos         0.0
# 1   48823  42.7620 -84.4539  East Lansing     51302.0
# 2   48824  42.7229 -84.4751  East Lansing      1158.0
# 3   48825  42.7270 -84.4809  East Lansing     12596.0
# 4   48826  42.7360 -84.4843  East Lansing         0.0
# 5   48840  42.7690 -84.3707       Haslett     12501.0
# 6   48842  42.6338 -84.5387          Holt     20432.0
# 7   48854  42.5820 -84.4517         Mason     18598.0
# 8   48864  42.7013 -84.4067        Okemos     20148.0
# 9   48901  42.7091 -84.5540       Lansing         0.0
# 10  48906  42.7845 -84.5875       Lansing     26634.0
# 11  48909  42.7311 -84.5526       Lansing         0.0
# 12  48910  42.6985 -84.5230       Lansing     34560.0
# 13  48911  42.6745 -84.5709       Lansing     40111.0
# 14  48912  42.7402 -84.5235       Lansing     17035.0
# 15  48915  42.7383 -84.5710       Lansing      9218.0
# 16  48917  42.7238 -84.6400       Lansing     32062.0
# 17  48933  42.7325 -84.5543       Lansing      2530.0
# 18  48951  42.7300 -84.5622       Lansing         0.0

# %% [markdown]
# Drop rows for population equals to 0.

# %%
lasing = lasing.loc[(lasing.population!=0)]
lasing.reset_index(inplace=True)
lasing
# Out:
#     index    zip      lat      lng          city  population
# 0       1  48823  42.7620 -84.4539  East Lansing     51302.0
# 1       2  48824  42.7229 -84.4751  East Lansing      1158.0
# 2       3  48825  42.7270 -84.4809  East Lansing     12596.0
# 3       5  48840  42.7690 -84.3707       Haslett     12501.0
# 4       6  48842  42.6338 -84.5387          Holt     20432.0
# 5       7  48854  42.5820 -84.4517         Mason     18598.0
# 6       8  48864  42.7013 -84.4067        Okemos     20148.0
# 7      10  48906  42.7845 -84.5875       Lansing     26634.0
# 8      12  48910  42.6985 -84.5230       Lansing     34560.0
# 9      13  48911  42.6745 -84.5709       Lansing     40111.0
# 10     14  48912  42.7402 -84.5235       Lansing     17035.0
# 11     15  48915  42.7383 -84.5710       Lansing      9218.0
# 12     16  48917  42.7238 -84.6400       Lansing     32062.0
# 13     17  48933  42.7325 -84.5543       Lansing      2530.0

# %%
lasing = lasing.drop('index',axis=1)
lasing
# Out:
#       zip      lat      lng          city  population
# 0   48823  42.7620 -84.4539  East Lansing     51302.0
# 1   48824  42.7229 -84.4751  East Lansing      1158.0
# 2   48825  42.7270 -84.4809  East Lansing     12596.0
# 3   48840  42.7690 -84.3707       Haslett     12501.0
# 4   48842  42.6338 -84.5387          Holt     20432.0
# 5   48854  42.5820 -84.4517         Mason     18598.0
# 6   48864  42.7013 -84.4067        Okemos     20148.0
# 7   48906  42.7845 -84.5875       Lansing     26634.0
# 8   48910  42.6985 -84.5230       Lansing     34560.0
# 9   48911  42.6745 -84.5709       Lansing     40111.0
# 10  48912  42.7402 -84.5235       Lansing     17035.0
# 11  48915  42.7383 -84.5710       Lansing      9218.0
# 12  48917  42.7238 -84.6400       Lansing     32062.0
# 13  48933  42.7325 -84.5543       Lansing      2530.0

# %% [markdown]
# ##  Load the map of the Lansing city

# %%
address = 'Okemos'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Lasing City are {}, {}.'.format(latitude, longitude))
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Lasing City are 42.721839, -84.428183.

# %%
# create map of GrantLasing using latitude and longitude values
map_Lasing = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for index, row in lasing.iterrows():
    lat=row['lat']
    lng=row['lng']
    label = '{}, {}'.format(lat, lng)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Lasing)  
    

map_Lasing
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  Use Foursquare to locate venues in each zipcode region

# %%
CLIENT_ID = 'TZYJYLLSQ5HZRMVW3KJHYFOVE4KSJBYPSPSLYLDHF1S4W2F3' # your Foursquare ID
CLIENT_SECRET = '002A5X02OMCARFUEF3KEGYCHLYRZ3CVJK5EKVMCFIBU401VG' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 300
radius = 10000 
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID:
# 64        42.733651       -84.477592           Asian Restaurant
# 76        42.735460       -84.480563        American Restaurant
# 79        42.734027       -84.478630           Asian Restaurant
# 85        42.735245       -84.483794        American Restaurant
# 88        42.726838       -84.480552           Asian Restaurant
# 89        42.735266       -84.480185           Asian Restaurant
# 92        42.734292       -84.479682           Asian Restaurant
# 94        42.733288       -84.476270       Fast Food Restaurant
# 100       42.735571       -84.481198         Mexican Restaurant
# 109       42.726702       -84.480639   Mediterranean Restaurant
# 111       42.734631       -84.481061        American Restaurant
# 123       42.731915       -84.470794           Asian Restaurant
# 129       42.626097       -84.542892        American Restaurant
# 135       42.580273       -84.444224        American Restaurant
# 143       42.589526       -84.457416        American Restaurant
# 148       42.588597       -84.457492       Fast Food Restaurant
# 149       42.578423       -84.443030         Mexican Restaurant
# 153       42.589086       -84.456464       Fast Food Restaurant
# 175       42.743543       -84.518173           Cuban Restaurant
# 177       42.733687       -84.530397        American Restaurant
# 191       42.733419       -84.516751       Fast Food Restaurant
# 203       42.733775       -84.522140           Asian Restaurant
# 204       42.733764       -84.521349       Cantonese Restaurant
# 214       42.741230       -84.566597         Mexican Restaurant
# 226       42.741336       -84.579231                 Restaurant
# 236       42.727086       -84.641614       Fast Food Restaurant
# 246       42.733489       -84.551934                 Restaurant
# 247       42.730965       -84.552076  Middle Eastern Restaurant
# 253       42.731015       -84.552117         Mexican Restaurant
# 262       42.732155       -84.552381  Middle Eastern Restaurant
# 264       42.729833       -84.552305           Asian Restaurant
# 278       42.732674       -84.551729           Asian Restaurant
# 279       42.733792       -84.551936    New American Restaurant
# 293       42.732654       -84.551798         Mexican Restaurant
# 294       42.733424       -84.547427       Fast Food Restaurant
# 297       42.729125       -84.552149       Caribbean Restaurant

# %% [markdown]
# ### The number of Asian restaurant and Non-asian restaurant

# %%
ax = sns.countplot(x='Venue Category',data=lasing_Restaurant)

ax.set_title('Number for Restaurant Type',size=20,color='purple')
ax.set_ylabel('Number',color='blue',size=20)
ax.set_xlabel('Restaurant Type',color='blue',size=20)
ax.set_yticklabels([0,2,4,6,8,10,12], rotation=0,color='red',size=15)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90,color='red',size=15);

# %%
ax = sns.countplot(x='zip',data=lasing_Restaurant)

ax.set_title('Number for Restaurant Type',size=20,color='purple')
ax.set_ylabel('Number',color='blue',size=20)
ax.set_xlabel('Restaurant Type',color='blue',size=20)
#ax.set_yticklabels([0,2,4,6,8,10,12], rotation=0,color='red',size=15)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90,color='red',size=15);

# %% [markdown]
# ### Distribution of Asian restaurant and Non-asian restaurant in each zipcode region

# %%
lansing2 = lasing_Restaurant.groupby('zip').count()
lansing2_merged = lansing2.join(lasing.set_index('zip'),on= 'zip')
lansing2_merged['Population_Per']=lansing2_merged['population']/lansing2_merged['Venue']
lansing2_merged.drop(['zip Latitude','zip Longitude','Venue Category','Venue Latitude','Venue Longitude'],1,inplace=True)
lansing2_merged.reset_index(inplace=True)

# %%
lansing2_merged
# Out:
#      zip  Venue      lat      lng          city  population  Population_Per
# 0  48823      1  42.7620 -84.4539  East Lansing     51302.0        51302.00
# 1  48824      2  42.7229 -84.4751  East Lansing      1158.0          579.00
# 2  48825     16  42.7270 -84.4809  East Lansing     12596.0          787.25
# 3  48842      1  42.6338 -84.5387          Holt     20432.0        20432.00
# 4  48854      5  42.5820 -84.4517         Mason     18598.0         3719.60
# 5  48912      5  42.7402 -84.5235       Lansing     17035.0         3407.00
# 6  48915      2  42.7383 -84.5710       Lansing      9218.0         4609.00
# 7  48917      1  42.7238 -84.6400       Lansing     32062.0        32062.00
# 8  48933     10  42.7325 -84.5543       Lansing      2530.0          253.00

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.bar(lansing2_merged.zip, lansing2_merged.Population_Per)

ax.set_title('People/Restaurant in each zipcode region',size=20,color='purple')
ax.set_ylabel('Number',color='blue',size=20)
ax.set_xlabel('Restaurant Type',color='blue',size=20);

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.bar(lansing2_merged.zip, lansing2_merged.population)

ax.set_title('Population in each zipcode region',size=20,color='purple')
ax.set_ylabel('Number',color='blue',size=20)
ax.set_xlabel('Restaurant Type',color='blue',size=20);

# %%
# one hot encoding
lasing_onehot = pd.get_dummies(lasing_Restaurant[['Venue Category']], prefix="", prefix_sep="")

lasing_onehot['zip'] = lasing_Restaurant['zip'] 

fixed_columns = [lasing_onehot.columns[-1]] + list(lasing_onehot.columns[:-1])
lasing_onehot = lasing_onehot[fixed_columns]

lasing_onehot.head()
# Out:
#       zip  American Restaurant  Asian Restaurant  Cantonese Restaurant  \
# 3   48823                    0                 1                     0
# 17  48824                    0                 1                     0
# 27  48824                    0                 0                     0
# 40  48825                    0                 0                     0
# 57  48825                    0                 1                     0
#
#     Caribbean Restaurant  Cuban Restaurant  Fast Food Restaurant  \
# 3                      0                 0                     0
# 17                     0                 0                     0
# 27                     0                 0                     0
# 40                     0                 0                     0
# 57                     0                 0                     0
#
#     Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 3                          0                   0                          0
# 17                         0                   0                          0
# 27                         1                   0                          0
# 40                         0                   1                          0
# 57                         0                   0                          0
#
#     New American Restaurant  Restaurant
# 3                         0           0
# 17                        0           0
# 27                        0           0
# 40                        0           0
# 57                        0           0

# %%
lasing_grouped = lasing_onehot.groupby('zip').mean().reset_index()
lasing_grouped
# Out:
#      zip  American Restaurant  Asian Restaurant  Cantonese Restaurant  \
# 0  48823               0.0000               1.0                   0.0
# 1  48824               0.0000               0.5                   0.0
# 2  48825               0.1875               0.5                   0.0
# 3  48842               1.0000               0.0                   0.0
# 4  48854               0.4000               0.0                   0.0
# 5  48912               0.2000               0.2                   0.2
# 6  48915               0.0000               0.0                   0.0
# 7  48917               0.0000               0.0                   0.0
# 8  48933               0.0000               0.2                   0.0
#
#    Caribbean Restaurant  Cuban Restaurant  Fast Food Restaurant  \
# 0                   0.0               0.0                0.0000
# 1                   0.0               0.0                0.0000
# 2                   0.0               0.0                0.0625
# 3                   0.0               0.0                0.0000
# 4                   0.0               0.0                0.4000
# 5                   0.0               0.2                0.2000
# 6                   0.0               0.0                0.0000
# 7                   0.0               0.0                1.0000
# 8                   0.1               0.0                0.1000
#
#    Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0                    0.0000               0.000                        0.0
# 1                    0.5000               0.000                        0.0
# 2                    0.0625               0.125                        0.0
# 3                    0.0000               0.000                        0.0
# 4                    0.0000               0.200                        0.0
# 5                    0.0000               0.000                        0.0
# 6                    0.0000               0.500                        0.0
# 7                    0.0000               0.000                        0.0
# 8                    0.0000               0.200                        0.2
#
#    New American Restaurant  Restaurant
# 0                      0.0      0.0000
# 1                      0.0      0.0000
# 2                      0.0      0.0625
# 3                      0.0      0.0000
# 4                      0.0      0.0000
# 5                      0.0      0.0000
# 6                      0.0      0.5000
# 7                      0.0      0.0000
# 8                      0.1      0.1000

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 9

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['zip']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Popular'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Popular'.format(ind+1))

# create a new dataframe
zip_venues_sorted = pd.DataFrame(columns=columns)
zip_venues_sorted['zip'] = lasing_grouped['zip']

for ind in np.arange(lasing_grouped.shape[0]):
    zip_venues_sorted.iloc[ind, 1:] = return_most_common_venues(lasing_grouped.iloc[ind, :], num_top_venues)

zip_venues_sorted
# Out:
#      zip           1st Most Popular     2nd Most Popular  \
# 0  48823           Asian Restaurant           Restaurant
# 1  48824   Mediterranean Restaurant     Asian Restaurant
# 2  48825           Asian Restaurant  American Restaurant
# 3  48842        American Restaurant           Restaurant
# 4  48854       Fast Food Restaurant  American Restaurant
# 5  48912       Fast Food Restaurant     Cuban Restaurant
# 6  48915                 Restaurant   Mexican Restaurant
# 7  48917       Fast Food Restaurant           Restaurant
# 8  48933  Middle Eastern Restaurant   Mexican Restaurant
#
#           3rd Most Popular           4th Most Popular  \
# 0  New American Restaurant  Middle Eastern Restaurant
# 1               Restaurant    New American Restaurant
# 2       Mexican Restaurant                 Restaurant
# 3  New American Restaurant  Middle Eastern Restaurant
# 4       Mexican Restaurant                 Restaurant
# 5     Cantonese Restaurant           Asian Restaurant
# 6  New American Restaurant  Middle Eastern Restaurant
# 7  New American Restaurant  Middle Eastern Restaurant
# 8         Asian Restaurant                 Restaurant
#
#             5th Most Popular           6th Most Popular  \
# 0         Mexican Restaurant   Mediterranean Restaurant
# 1  Middle Eastern Restaurant         Mexican Restaurant
# 2   Mediterranean Restaurant       Fast Food Restaurant
# 3         Mexican Restaurant   Mediterranean Restaurant
# 4    New American Restaurant  Middle Eastern Restaurant
# 5        American Restaurant                 Restaurant
# 6   Mediterranean Restaurant       Fast Food Restaurant
# 7         Mexican Restaurant   Mediterranean Restaurant
# 8    New American Restaurant       Fast Food Restaurant
#
#            7th Most Popular           8th Most Popular      9th Most Popular
# 0      Fast Food Restaurant           Cuban Restaurant  Caribbean Restaurant
# 1      Fast Food Restaurant           Cuban Restaurant  Caribbean Restaurant
# 2   New American Restaurant  Middle Eastern Restaurant      Cuban Restaurant
# 3      Fast Food Restaurant           Cuban Restaurant  Caribbean Restaurant
# 4  Mediterranean Restaurant           Cuban Restaurant  Caribbean Restaurant
# 5   New American Restaurant  Middle Eastern Restaurant    Mexican Restaurant
# 6          Cuban Restaurant       Caribbean Restaurant  Cantonese Restaurant
# 7          Cuban Restaurant       Caribbean Restaurant  Cantonese Restaurant
# 8      Caribbean Restaurant   Mediterranean Restaurant      Cuban Restaurant

# %%
lasing_grouped = lasing_grouped.join(lansing2_merged.set_index('zip'),on= 'zip')
lasing_grouped
# Out:
#      zip  American Restaurant  Asian Restaurant  Cantonese Restaurant  \
# 0  48823               0.0000               1.0                   0.0
# 1  48824               0.0000               0.5                   0.0
# 2  48825               0.1875               0.5                   0.0
# 3  48842               1.0000               0.0                   0.0
# 4  48854               0.4000               0.0                   0.0
# 5  48912               0.2000               0.2                   0.2
# 6  48915               0.0000               0.0                   0.0
# 7  48917               0.0000               0.0                   0.0
# 8  48933               0.0000               0.2                   0.0
#
#    Caribbean Restaurant  Cuban Restaurant  Fast Food Restaurant  \
# 0                   0.0               0.0                0.0000
# 1                   0.0               0.0                0.0000
# 2                   0.0               0.0                0.0625
# 3                   0.0               0.0                0.0000
# 4                   0.0               0.0                0.4000
# 5                   0.0               0.2                0.2000
# 6                   0.0               0.0                0.0000
# 7                   0.0               0.0                1.0000
# 8                   0.1               0.0                0.1000
#
#    Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0                    0.0000               0.000                        0.0
# 1                    0.5000               0.000                        0.0
# 2                    0.0625               0.125                        0.0
# 3                    0.0000               0.000                        0.0
# 4                    0.0000               0.200                        0.0
# 5                    0.0000               0.000                        0.0
# 6                    0.0000               0.500                        0.0
# 7                    0.0000               0.000                        0.0
# 8                    0.0000               0.200                        0.2
#
#    New American Restaurant  Restaurant  Venue      lat      lng          city  \
# 0                      0.0      0.0000      1  42.7620 -84.4539  East Lansing
# 1                      0.0      0.0000      2  42.7229 -84.4751  East Lansing
# 2                      0.0      0.0625     16  42.7270 -84.4809  East Lansing
# 3                      0.0      0.0000      1  42.6338 -84.5387          Holt
# 4                      0.0      0.0000      5  42.5820 -84.4517         Mason
# 5                      0.0      0.0000      5  42.7402 -84.5235       Lansing
# 6                      0.0      0.5000      2  42.7383 -84.5710       Lansing
# 7                      0.0      0.0000      1  42.7238 -84.6400       Lansing
# 8                      0.1      0.1000     10  42.7325 -84.5543       Lansing
#
#    population  Population_Per
# 0     51302.0        51302.00
# 1      1158.0          579.00
# 2     12596.0          787.25
# 3     20432.0        20432.00
# 4     18598.0         3719.60
# 5     17035.0         3407.00
# 6      9218.0         4609.00
# 7     32062.0        32062.00
# 8      2530.0          253.00

# %% [markdown]
# ### Use k-means to cluster those venues

# %%
# set number of clusters
kclusters = 5

lasing_grouped_clustering = lasing_grouped.drop(['zip','Venue','lat','lng','population','city'], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(lasing_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:]
# Out:
# array([2, 4, 4, 3, 0, 0, 0, 1, 4])

# %%
lasing_grouped['Cluster Labels'] = kmeans.labels_
lasing_grouped
# Out:
#      zip  American Restaurant  Asian Restaurant  Cantonese Restaurant  \
# 0  48823               0.0000               1.0                   0.0
# 1  48824               0.0000               0.5                   0.0
# 2  48825               0.1875               0.5                   0.0
# 3  48842               1.0000               0.0                   0.0
# 4  48854               0.4000               0.0                   0.0
# 5  48912               0.2000               0.2                   0.2
# 6  48915               0.0000               0.0                   0.0
# 7  48917               0.0000               0.0                   0.0
# 8  48933               0.0000               0.2                   0.0
#
#    Caribbean Restaurant  Cuban Restaurant  Fast Food Restaurant  \
# 0                   0.0               0.0                0.0000
# 1                   0.0               0.0                0.0000
# 2                   0.0               0.0                0.0625
# 3                   0.0               0.0                0.0000
# 4                   0.0               0.0                0.4000
# 5                   0.0               0.2                0.2000
# 6                   0.0               0.0                0.0000
# 7                   0.0               0.0                1.0000
# 8                   0.1               0.0                0.1000
#
#    Mediterranean Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0                    0.0000               0.000                        0.0
# 1                    0.5000               0.000                        0.0
# 2                    0.0625               0.125                        0.0
# 3                    0.0000               0.000                        0.0
# 4                    0.0000               0.200                        0.0
# 5                    0.0000               0.000                        0.0
# 6                    0.0000               0.500                        0.0
# 7                    0.0000               0.000                        0.0
# 8                    0.0000               0.200                        0.2
#
#    New American Restaurant  Restaurant  Venue      lat      lng          city  \
# 0                      0.0      0.0000      1  42.7620 -84.4539  East Lansing
# 1                      0.0      0.0000      2  42.7229 -84.4751  East Lansing
# 2                      0.0      0.0625     16  42.7270 -84.4809  East Lansing
# 3                      0.0      0.0000      1  42.6338 -84.5387          Holt
# 4                      0.0      0.0000      5  42.5820 -84.4517         Mason
# 5                      0.0      0.0000      5  42.7402 -84.5235       Lansing
# 6                      0.0      0.5000      2  42.7383 -84.5710       Lansing
# 7                      0.0      0.0000      1  42.7238 -84.6400       Lansing
# 8                      0.1      0.1000     10  42.7325 -84.5543       Lansing
#
#    population  Population_Per  Cluster Labels
# 0     51302.0        51302.00               2
# 1      1158.0          579.00               4
# 2     12596.0          787.25               4
# 3     20432.0        20432.00               3
# 4     18598.0         3719.60               0
# 5     17035.0         3407.00               0
# 6      9218.0         4609.00               0
# 7     32062.0        32062.00               1
# 8      2530.0          253.00               4

# %%
cluster_region1=lasing_grouped[['zip','Cluster Labels']]
cluster_region2=zip_venues_sorted[['zip','1st Most Popular']]
cluster_region = cluster_region1.join(cluster_region2.set_index('zip'),on= 'zip')
cluster_region
# Out:
#      zip  Cluster Labels           1st Most Popular
# 0  48823               2           Asian Restaurant
# 1  48824               4   Mediterranean Restaurant
# 2  48825               4           Asian Restaurant
# 3  48842               3        American Restaurant
# 4  48854               0       Fast Food Restaurant
# 5  48912               0       Fast Food Restaurant
# 6  48915               0                 Restaurant
# 7  48917               1       Fast Food Restaurant
# 8  48933               4  Middle Eastern Restaurant

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(lasing_grouped['lat'], lasing_grouped['lng'], lasing_grouped['zip'], lasing_grouped['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

#folium.CircleMarker([42.762,-84.4539],radius=15,color='blue').add_to(map_clusters)    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Conclusion
# People in **Cluster 2** region like Asian food. The most popular restaurant is Asian Restaurant. So cluster 2 region is an good place to operate a Asian restaurant.

# %%
Asian_restaurant = lasing_grouped.loc[lasing_grouped['Cluster Labels'] == 2]

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Asian_restaurant['lat'], Asian_restaurant['lng'], Asian_restaurant['zip'], Asian_restaurant['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_clusters)
folium.CircleMarker([42.762,-84.4539],radius=10,color='yellow').add_to(map_clusters)    
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##   The best place to open an Asian Restaurant is at 48823 region.
